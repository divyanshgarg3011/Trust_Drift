# %% [markdown]
# # TrustDrift — harness smoke test
#
# Run the two cells below in order. No API key, no GPU, no setup.
# Takes about ten seconds.

# %% [markdown]
# ### Step 1 — upload the code
#
# Run this cell, then click **Choose Files** and select `trustdrift-repo.zip`.

# %%
from google.colab import files
import zipfile, os
up = files.upload()
name = list(up.keys())[0]
with zipfile.ZipFile(name) as z:
    z.extractall('.')
os.chdir('src' if os.path.isdir('src') else '.')
print('working directory:', os.getcwd())
print('files:', sorted(os.listdir('.')))

# %% [markdown]
# ### Step 2 — run the harness
#
# This is the output to screenshot for your presentation.

# %%
# !python run_demo.py
